# %%
import pandas as pd

# %%
data = pd.read_csv('/home/aleksey/Downloads/sends_july_dec_2019_2000', header=None, sep='\t', usecols=[66,68]) #, chunksize=5000000)

# %%
data.head()
# Out:
#                                                   66  \
# 0                                It’s almost the end
# 1  <#include "cms://messagelibrary/email/59253142...
# 2  <#include "cms://messagelibrary/email/59253042...
# 3  <#include "cms://messagelibrary/email/59251982...
# 4  <#include "cms://messagelibrary/email/59252822...
#
#                                                   68
# 0  20190811_US_Dockers_Tops_GraphicTees_30off_FS_...
# 1                  DOC_WelNoPurchT4_Trigger_20191226
# 2                  DOC_WelNoPurchT3_Trigger_20191226
# 3                  DOC_WelNoPurchT1_Trigger_20191226
# 4                  DOC_WelNoPurchT2_Trigger_20191226

# %%
num_rows = len(data.index)
to_drop = []

for index, row in data.iterrows():
    if index % 10000 == 0:
        print (index)
    if 'DOC_' in row[68]:
        to_drop.append(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
print ("Total emails:", num_rows)
print ("Reminders:", len(to_drop))
# Out:
# Total emails: 37789264
# Reminders: 783519

# %%
data_cut = data.drop(to_drop, axis='rows')

# %%
data_cut.head()
# Out:
#                                               66  \
# 0                            It’s almost the end
# 5  50% off absolutely everything + free shipping
# 6  50% off absolutely everything + free shipping
# 8                   Free shipping + free returns
# 9        These should get you through the winter
#
#                                                   68
# 0  20190811_US_Dockers_Tops_GraphicTees_30off_FS_...
# 5  20191129_US_Dockers_Dedicated_BF_50Off_FSFR_AM...
# 6  20191129_US_Dockers_Dedicated_BF_50Off_FSFR_AM...
# 8  20191214_US_Dockers_Dedicated_LPOS_Upto50_FSFR...
# 9  20191121_US_Dockers_Trend_ColdWeatherEssential...

# %%
data_cut.to_csv('/home/aleksey/Downloads/Subjects_Types.csv', header=False)

# %%
lst = [data]
del data
del lst

# %%
to_drop = []
for index, row in data_cut.iterrows():
    if index % 10000 == 0:
        print (index)
    if '_US_' not in row[68]:
        to_drop.append(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# ...

# %%
print ("International:", len(to_drop))
# Out:
# International: 29708

# %%
data_cut2 = data_cut.drop(to_drop, axis='rows')

# %%
data_cut2.to_csv('/home/aleksey/Downloads/Subjects_Types_US.csv', header=False)

# %%
lst = [data_cut]
del data_cut
del lst

# %%
snippet = pd.read_csv('/home/aleksey/Desktop/FellowshipAI/data_snippet.csv')

# %%
cts = snippet['campaign_type'].unique()
print(cts)
cts[2] = 'InnovationSpotlight'
cts[4] = 'NewArrivals'
cts[5] = 'ProductSpotlight'
cts = cts.tolist()
cts.pop(-1)
print(cts)
# Out:
# ['Dedicated' 'Core' 'Innovation Spotlight' 'Trend' 'New Arrivals'
#  'Product Spotlight' 'Brand' 'Tops' 'Replen' 'Collection' 'Other']
# ['Dedicated', 'Core', 'InnovationSpotlight', 'Trend', 'NewArrivals', 'ProductSpotlight', 'Brand', 'Tops', 'Replen', 'Collection']

# %%
lst = [snippet]
del snippet
del lst

# %%
numbers = {}
for ct in cts:
    numbers[ct] = 0
numbers['Other'] = 0

print (numbers)
# Out:
# {'Dedicated': 0, 'Core': 0, 'InnovationSpotlight': 0, 'Trend': 0, 'NewArrivals': 0, 'ProductSpotlight': 0, 'Brand': 0, 'Tops': 0, 'Replen': 0, 'Collection': 0, 'Other': 0}

# %%
to_drop = []
for index, row in data_cut2.iterrows():

    if index % 10000 == 0:
        print (index)
        
    flag = False
    for ct in cts:
        if ct in row[68]:
            flag = True
            numbers[ct] += 1

    if flag == False:
        numbers['Other'] += 1
        to_drop.append(index)
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# ...

# %%
print ("Other:", len(to_drop))
# Out:
# Other: 2139175

# %%
print (numbers)
# Out:
# {'Dedicated': 13009567, 'Core': 7284131, 'InnovationSpotlight': 1000444, 'Trend': 6999863, 'NewArrivals': 1235362, 'ProductSpotlight': 922195, 'Brand': 2854407, 'Tops': 1530893, 'Replen': 0, 'Collection': 0, 'Other': 2139175}

# %%
data_cut3 = data_cut2.drop(to_drop, axis='rows')

# %%
data_cut3.to_csv('/home/aleksey/Downloads/Subjects_Types_Clean.csv', header=False)
